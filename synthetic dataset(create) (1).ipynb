# %%
import pandas as pd
import random
unique_integers = []

# Generate 900 unique integers
while len(unique_integers) < 10000:
    # Generate a random four-digit integer
    num = random.randint(1000, 9999)
    
    # Check if the integer is not already in the list
    if num not in unique_integers:
        unique_integers.append(num)
injuries = ["ACL Tear", "Meniscus Tear", "Patellar Tendinitis", "Osgood-Schlatter",
    "Ankle Sprain", "Ankle Strain", "Plantar Fasciitis", "Achilles Tendinitis",
    "Hip Bursitis", "Hip Labral Tear", "Hip Arthritis",
    "Rotator Cuff Tear", "Labrum Tear", "Shoulder Bursitis", "Frozen Shoulder",
    "Tennis Elbow", "Golfer's Elbow", "Wrist Carpal Tunnel", "Wrist Sprain", "Wrist Strain",
    "Scoliosis", "Kyphosis", "Lordosis"]

sex=['Female','Male']

injury_goal_map = {
  "ACL Tear": ["Improved ROM (Knee)", "Increased Strength (Knee)"],
  "Meniscus Tear": ["Improved ROM (Knee)", "Reduced Pain (Knee)"],
  "Patellar Tendinitis": ["Reduced Pain (Knee)", "Increased Flexibility (Knee)"],
  "Osgood-Schlatter": ["Reduced Pain (Knee)", "Reduced Inflammation (Knee)"],
  "Ankle Sprain": ["Improved ROM (Ankle)", "Improved Stability (Ankle)"],
  "Ankle Strain": ["Reduced Pain (Ankle)", "Improved Flexibility (Ankle)"],
  "Plantar Fasciitis": ["Reduced Pain (Plantar Fascia)", "Improved Flexibility (Plantar Fascia)"],
  "Achilles Tendinitis": ["Reduced Pain (Achilles Tendon)", "Increased Strength (Calf)"],
  "Hip Bursitis": ["Reduced Pain (Hip)", "Improved Flexibility (Hip)"],
  "Hip Labral Tear": ["Improved ROM (Hip)", "Increased Strength (Hip)"],
  "Hip Arthritis": ["Reduced Pain (Hip)", "Improved Joint Mobility (Hip)"],
  "Rotator Cuff Tear": ["Improved ROM (Shoulder)", "Increased Strength (Shoulder)"],
  "Labrum Tear": ["Improved ROM (Shoulder)", "Improved Stability (Shoulder)"],
  "Shoulder Bursitis": ["Reduced Pain (Shoulder)", "Improved Flexibility (Shoulder)"],
  "Frozen Shoulder": ["Improved ROM (Shoulder)", "Improved Flexibility (Shoulder)"],
  "Tennis Elbow": ["Reduced Pain (Elbow)", "Improved Strength (Forearm)"],
  "Golfer's Elbow": ["Reduced Pain (Elbow)", "Improved Strength (Forearm)"],
  "Wrist Carpal Tunnel": ["Reduced Pain (Wrist)", "Improved Flexibility (Wrist)"],
  "Wrist Sprain": ["Improved ROM (Wrist)", "Improved Stability (Wrist)"],
  "Wrist Strain": ["Reduced Pain (Wrist)", "Improved Flexibility (Wrist)"],
  "Scoliosis": ["Improved Posture", "Increased Core Strength"],
  "Kyphosis": ["Improved Posture", "Strengthening Posterior Chain Muscles"],
  "Lordosis": ["Improved Posture", "Strengthening Abdominal Muscles"]
}


injury_exercise_map = {
    "ACL Tear": [
        "Walking Squats (modified)",
        "Lunges (forward/reverse, bodyweight)",
        "Hamstring Curls (light weight)",
        "Calf Raises (seated)",
        "Ankle Circles",
        "Plank (high)",
    ],
    "Meniscus Tear": [
        "Walking Squats (modified)",
        "Short Arc Quad Sets",
        "Hamstring Curls (light weight)",
        "Calf Raises (seated)",
        "Ankle Circles",
        "Side Plank",
    ],
    "Patellar Tendinitis": [
        "Wall Sits",
        "Quad Extensions (isometric)",
        "Hamstring Curls (light weight)",
        "Calf Raises (seated)",
        "Ankle Circles",
        "Plank (high)",
    ],
    "Osgood-Schlatter": [
        "Straight Leg Raises",
        "Hamstring Curls (light weight)",
        "Calf Raises (seated)",
        "Ankle Circles",
        "Bird Dog",
    ],
    "Ankle Sprain": [
        "Calf Raises (seated)",
        "Ankle Circles (both directions)",
        "Towel Toe Curls",
        "Balance Exercises (single leg stance)",
    ],
    "Ankle Strain": [
        "Calf Raises (seated)",
        "Ankle Circles (both directions)",
        "Plantar Fascia Massage",
        "Balance Exercises (single leg stance)",
    ],
    "Plantar Fasciitis": [
        "Calf Stretches",
        "Plantar Fascia Massage",
        "Towel Toe Curls",
        "Short Foot Exercises",
    ],
    "Achilles Tendinitis": [
        "Eccentric Heel Drops",
        "Calf Raises (seated)",
        "Ankle Circles (both directions)",
        "Wall Sits",
    ],
    "Hip Bursitis": [
        "Glute Bridges",
        "Clamshells",
        "Hip Flexor Stretches",
        "Side Plank",
    ],
    "Hip Labral Tear": [
        "Glute Bridges",
        "External Rotations",
        "Internal Rotations (light weight)",
        "Plank (high)",
    ],
    "Hip Arthritis": [
        "Range of Motion Exercises (hip)",
        "Water Exercises (walking, aerobics)",
        "Glute Bridges",
    ],
    "Rotator Cuff Tear": [
        "Pendulum Exercises",
        "External Rotations (light weight)",
        "Internal Rotations (isometric)",
        "Scapular Retractions",
    ],
    "Labrum Tear": [
        "Pendulum Exercises",
        "External Rotations (light weight)",
        "Internal Rotations (isometric)",
        "Plank (high)",
    ],
    "Shoulder Bursitis": [
        "Pendulum Exercises",
        "Scapular Retractions",
        "Posture Exercises",
        "Plank (high)",
    ],
    "Frozen Shoulder": [
        "Passive Range of Motion Exercises (shoulder)",
        "Heat Therapy",
        "Doorway Shoulder Stretches",
    ],
    "Tennis Elbow": [
        "Wrist Extensor Stretches",
        "Eccentric Wrist Extensions",
        "Grip Strengthening Exercises",
    ],
    "Golfer's Elbow": [
        "Wrist Flexor Stretches",
        "Eccentric Wrist Flexions",
        "Grip Strengthening Exercises",
    ],
    "Wrist Carpal Tunnel": [
        "Wrist Stretches",
        "Wrist Flexor Stretches",
        "Wrist Extensor Stretches",
        "Grip Strengthening Exercises",
    ],
    "Wrist Sprain": [
        "Wrist Stretches",
        "Wrist Flexor Stretches",
        "Wrist Extensor Stretches",
        "Grip Strengthening Exercises",
    ],
    "Wrist Strain": [
        "Wrist Stretches",
        "Wrist Flexor Stretches",
        "Wrist Extensor Stretches",
        "Grip Strengthening Exercises",
    ],
    "Scoliosis": [
        "Stretching Exercises",
        "Core Strengthening Exercises",
        "Back Extension Exercises",
        "Pilates",
    ],
    "Kyphosis": [
        "Stretching Exercises",
        "Posture Correction Exercises",
        "Thoracic Extension Exercises",
        "Strengthening Exercises (Back and Shoulders)",
    ],
    "Lordosis": [
        "Stretching Exercises",
        "Core Strengthening Exercises",
        "Pelvic Tilt Exercises",
        "Strengthening Exercises (Abs and Lower Back)",
    ]}


data = pd.DataFrame(columns=["Patient ID", "Age","Gender", "Injury",'Pain Level', "Goal",'Exercise 1','Exercise 2','Exercise 3', "E1_sets", "E1_reps","E2_sets", "E2_reps","E3_sets", "E3_reps","Improvement Score"])

for i in range(1,700):
    uhid = unique_integers[i]
    gender=random.choice(sex)
    age = random.randint(20, 65)
    injury = random.choice(injuries)
    pain=random.randint(0,10)
    if injury in injury_goal_map:
        goal = random.choice(injury_goal_map[injury])
    else:
        goal = random.choice(["Goal1", "Goal2"])  # Default random goal selection
    if injury in injury_exercise_map:
        exercise_1 = random.choice(injury_exercise_map[injury])
    if injury in injury_exercise_map:
        exercise_2 = random.choice(injury_exercise_map[injury])
        while exercise_1 == exercise_2:
            exercise_2 = random.choice(injury_exercise_map[injury])
    if injury in injury_exercise_map:
        exercise_3 = random.choice(injury_exercise_map[injury])
        while exercise_1 == exercise_3 or exercise_2==exercise_3:
            exercise_3 = random.choice(injury_exercise_map[injury])
    E1_sets = random.randint(2, 4)
    E1_reps = random.randint(8, 12)
    E2_sets = random.randint(1, 4)
    E2_reps = random.randint(8, 12)
    E3_sets = random.randint(2, 4)
    E3_reps = random.randint(8, 12)
    improvement_score=random.randint(3,10)
    data.loc[i] = [uhid, age, gender, injury,pain, goal,exercise_1,exercise_2,exercise_3, E1_sets, E1_reps,E2_sets, E2_reps,E3_sets, E3_reps, improvement_score]

data.to_csv("synthetic_rehab_data.csv", index=False)

# %%
print(data)

# %%
data.head()
